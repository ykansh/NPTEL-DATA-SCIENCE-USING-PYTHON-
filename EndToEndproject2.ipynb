# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Crop_recommendation.csv")

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   N            2200 non-null   int64
#  1   P            2200 non-null   int64
#  2   K            2200 non-null   int64
#  3   temperature  2200 non-null   float64
#  4   humidity     2200 non-null   float64
#  5   ph           2200 non-null   float64
#  6   rainfall     2200 non-null   float64
#  7   label        2200 non-null   object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 137.6+ KB
#                  N            P            K  temperature     humidity  \
# count  2200.000000  2200.000000  2200.000000  2200.000000  2200.000000
# mean     50.551818    53.362727    48.149091    25.616244    71.481779
# std      36.917334    32.985883    50.647931     5.063749    22.263812
# min       0.000000     5.000000     5.000000     8.825675    14.258040
# ...

# %%
sns.histplot([df["temperature"],df["humidity"]], bins = 50 , kde = True , alpha = 0.8 , palette = ["green", "blue"])
# Out:
# <Axes: ylabel='Count'>

# %%
sns.heatmap(df.drop('label', axis=1).corr() , annot = True)
# Out:
# <Axes: >

# %%
sns.pairplot(df , hue = "label")

# %%
x = df.drop("label" , axis = 1)
y = df["label"]

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(x , y, test_size = 0.2 , random_state= 42)
dia_en = pd.DataFrame()
res = pd.DataFrame()

# %%
#from imblearn.over_sampling import SMOTE
#sm = SMOTE (random_state=42)
#X, Y = sm. fit_resample (X, Y)
from imblearn.over_sampling import RandomOverSampler
ros = RandomOverSampler(random_state=42)
x, y = ros. fit_resample (X, Y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3804401428.py in <cell line: 0>()
#       4 from imblearn.over_sampling import RandomOverSampler
#       5 ros = RandomOverSampler(random_state=42)
# ----> 6 x, y = ros. fit_resample (X, Y)
#
# NameError: name 'X' is not defined

# %%
from sklearn.metrics import precision_score , accuracy_score , recall_score , f1_score , roc_curve , auc , confusion_matrix , ConfusionMatrixDisplay
y2 = y_test.value_counts()
y2
# Out:
# label
# coconut        27
# chickpea       26
# mothbeans      24
# jute           23
# apple          23
# papaya         23
# pigeonpeas     23
# pomegranate    23
# maize          21
# banana         21
# kidneybeans    20
# blackgram      20
# watermelon     19
# mango          19
# mungbean       19
# rice           19
# muskmelon      17
# coffee         17
# cotton         17
# orange         14
# grapes         14
# lentil         11
# Name: count, dtype: int64

# %% [markdown]
# made 4 models tested them and ended session.
